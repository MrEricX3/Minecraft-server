# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]


if colabconfig["server_version"] < "1.17":
    #en la segunda linea de este if puedes cambiar la version de java que quieres instalar, (openjdk-𝟠-jre- (En el 8 puedes cambiarlo si lo necesitas dependiendo del error que te salga))
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-8-jre-headless &>/dev/null') and print("OpenJDK 8 installed") or print("Failed to install OpenJDK 8.")
# Instalar OpenJDK 17 si la version de Minecraft es 1.17 o superior
else:
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-17-jre-headless &>/dev/null') and print("OpenJDK 17 installed") or print("Failed to install OpenJDK 17.")

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dBhrnyZXkA599PBzdf7crHlAYx_ne65xuSPpiUmvhwo3X6o" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui
    
    
elif tunnel_service == "zerotier":
    # Instalar ZeroTier
    # !curl -s https://install.zerotier.com | sudo bash

    # Ingresar a tu red de ZeroTier
    zerotier_network_id = "YOUR_NETWORK_ID"  # Remplaza con tu id de red de ZeroTier
    # !sudo zerotier-cli join $zerotier_network_id

    # Esperar a que ZeroTier se una a la red
    import time
    time.sleep(120)  # Aumentalo si es neceasrio

    #Chequea el estado de ZeroTier
    # !sudo zerotier-cli status


print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      emotes	    mohist-config      spigot.yml
# banned-players.json  eula.txt	    mohist.jar	       user_jvm_args.txt
# bukkit.yml	     forge.jar	    ops.json	       usercache.json
# colabconfig.json     forge.jar.log  permissions.yml    usernamecache.json
# commands.yml	     help.yml	    plugins	       whitelist.json
# config		     libraries	    run.bat	       world
# crash-reports	     logs	    run.sh
# defaultconfigs	     mods	    server.properties
# Failed to install OpenJDK 17.
# Reading package lists...Usando ngrok
#
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   ca-certificates-java java-common libpcsclite1
# Suggested packages:
#   default-jre pcscd libnss-mdns fonts-dejavu-extra fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   ca-certificates-java java-common libpcsclite1 openjdk-17-jre-headless
# 0 upgraded, 4 newly installed, 0 to remove and 28 not upgraded.
# Need to get 43.7 MB of archives.
# After this operation, 193 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:16687
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 50763
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-591 but you have 1.20.1-580. The latest version has been built on 2024-03-03 14:05:20. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [19:35:23 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [19:35:23 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [19:35:24 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [19:35:24 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [19:35:24 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: apexcore. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/apexcore-1.20.1-10.0.0.jar
# [19:35:24 INFO]: Found 10 dependencies adding them to mods collection
# [19:35:26 INFO]: Compatibility level set to JAVA_17
# [19:35:27 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [19:35:27 WARN]: Reference map 'octolib.refmap.json' for octolib.mixins.json could not be read. If this is a development environment you can ignore this message
# [19:35:27 WARN]: Reference map 'graveyard-FORGE-forge-refmap.json' for graveyard-forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [19:35:27 INFO]: Loaded configuration file for Embeddium: 104 options available, 0 override(s) found
# [19:35:27 WARN]: Reference map 'apexcore.refmap.json' for apexcore.mixins.json could not be read. If this is a development environment you can ignore this message
# [19:35:27 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [19:35:28 ERROR]: Attempted to load class net/minecraft/client/gui/screens/Screen for invalid dist DEDICATED_SERVER
# [19:35:28 WARN]: Error loading class: net/minecraft/client/gui/screens/Screen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/Screen for invalid dist DEDICATED_SERVER)
# [19:35:28 WARN]: @Mixin target net.minecraft.client.gui.screens.Screen was not found relics.mixins.json:MixinScreen
# [19:35:29 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.2.1-beta.2).
# [19:35:32 WARN]: @Final field f_31427_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [19:35:32 WARN]: @Final field f_31428_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [19:35:33 WARN]: Method overwrite conflict for m_5995_ in map_atlases-common.mixins.json:LecternBlockEntityMixin, previously written by net.mehvahdjukaar.amendments.mixins.LecternBlockEntityMixin. Skipping method.
# [19:35:36 INFO]: Registered JSON trade offer adapter.
# [19:35:36 INFO]: Registered skill epicfight:epicfight:basic_attack
# [19:35:36 INFO]: Registered skill epicfight:epicfight:air_attack
# [19:35:36 INFO]: Registered skill epicfight:epicfight:roll
# [19:35:36 INFO]: Registered skill epicfight:epicfight:step
# [19:35:36 INFO]: Registered skill epicfight:epicfight:knockdown_wakeup
# [19:35:36 INFO]: Registered skill epicfight:epicfight:guard
# [19:35:36 INFO]: Registered skill epicfight:epicfight:parrying
# [19:35:36 INFO]: Registered skill epicfight:epicfight:impact_guard
# [19:35:36 INFO]: Registered skill epicfight:epicfight:berserker
# [19:35:36 INFO]: Registered skill epicfight:epicfight:death_harvest
# [19:35:37 INFO]: Registered skill epicfight:epicfight:emergency_escape
# [19:35:37 INFO]: Registered skill epicfight:epicfight:endurance
# [19:35:37 INFO]: Registered skill epicfight:epicfight:forbidden_strength
# [19:35:37 INFO]: Registered skill epicfight:epicfight:hypervitality
# [19:35:37 INFO]: Registered skill epicfight:epicfight:stamina_pillager
# [19:35:37 INFO]: Registered skill epicfight:epicfight:swordmaster
# [19:35:37 INFO]: Registered skill epicfight:epicfight:technician
# [19:35:37 INFO]: Registered skill epicfight:epicfight:sweeping_edge
# [19:35:37 INFO]: Registered skill epicfight:epicfight:dancing_edge
# [19:35:37 INFO]: Registered skill epicfight:epicfight:the_guillotine
# [19:35:37 INFO]: Registered skill epicfight:epicfight:grasping_spire
# [19:35:37 INFO]: Registered skill epicfight:epicfight:heartpiercer
# [19:35:37 INFO]: Registered skill epicfight:epicfight:steel_whirlwind
# [19:35:37 INFO]: Registered skill epicfight:epicfight:battojutsu
# [19:35:37 INFO]: Registered skill epicfight:epicfight:battojutsu_passive
# [19:35:37 INFO]: Registered skill epicfight:epicfight:rushing_tempo
# [19:35:37 INFO]: Registered skill epicfight:epicfight:relentless_combo
# [19:35:37 INFO]: Registered skill epicfight:epicfight:liechtenauer
# [19:35:37 INFO]: Registered skill epicfight:epicfight:sharp_stab
# [19:35:37 INFO]: Registered skill epicfight:epicfight:eviscerate
# [19:35:37 INFO]: Registered skill epicfight:epicfight:blade_rush
# [19:35:37 INFO]: Registered skill epicfight:epicfight:wrathful_lighting
# [19:35:37 INFO]: Registered skill epicfight:epicfight:tsunami
# [19:35:37 INFO]: Registered skill epicfight:epicfight:everlasting_allegiance
# [19:35:37 INFO]: Registered skill epicfight:epicfight:meteor_slam
# [19:35:37 INFO]: Registered skill epicfight:epicfight:revelation
# [19:35:37 INFO]: Registered skill epicfight:epicfight:demolition_leap
# [19:35:37 INFO]: Registered skill epicfight:epicfight:phantom_ascent
# [19:35:37 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [19:35:37 INFO]: MinecraftForge v47.2.20 Initialized
# [19:35:37 INFO]: NeoForge v47.2.20 Initialized
# [19:35:37 INFO]: Mohist mod loading.....
# [19:35:37 ERROR]: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER
# [19:35:37 ERROR]: Failed to update fingerprint
# java.lang.NoClassDefFoundError: net/minecraft/client/Minecraft
# 	at me.jellysquid.mods.sodium.client.data.fingerprint.FingerprintMeasure.create(FingerprintMeasure.java:19) ~[embeddium-0.3.7+mc1.20.1.jar%23263!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.updateFingerprint(SodiumClientMod.java:100) ~[embeddium-0.3.7+mc1.20.1.jar%23263!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.<init>(SodiumClientMod.java:41) ~[embeddium-0.3.7+mc1.20.1.jar%23263!/:?]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23298!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# Caused by: java.lang.ClassNotFoundException: net.minecraft.client.Minecraft
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	... 15 more
# [19:35:37 INFO]: EventDispatcherRegistry initialized
# [19:35:37 INFO]: Running Minecraft '1.20.1', & Forge '47.2.20' on Java '21.0.2, Microsoft'
# [19:35:37 INFO]: Loading BlackListed sources from remote... (https://api.stopmodreposts.org/minecraft/sites.txt)
# [19:35:37 INFO]: Loaded 564 BlackListed sources from remote
# [19:35:37 INFO]: Loading mod 'commonality' TrustWorthiness...
# [19:35:37 FATAL]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [19:35:37 INFO]: Loaded mod 'commonality' TrustWorthiness: UNKNOWN
# [19:35:38 INFO]: Registering C2S receiver with id architectury:sync_ids
# [19:35:38 INFO]: Loading mod 'apexcore' TrustWorthiness...
# [19:35:38 FATAL]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [19:35:38 INFO]: Loaded mod 'apexcore' TrustWorthiness: UNKNOWN
# [19:35:39 INFO]: Loading mod 'fantasyfurniture' TrustWorthiness...
# [19:35:39 FATAL]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [19:35:39 INFO]: Loaded mod 'fantasyfurniture' TrustWorthiness: UNKNOWN
# [19:35:39 INFO]: Registering C2S receiver with id magistuarmory:packet_long_reach_attack
# [19:35:39 INFO]: Registering C2S receiver with id magistuarmory:packet_lance_collision
# [19:35:43 INFO]: Initialized block sets in 16ms
# [19:35:43 ERROR]: Could not find parent net/minecraft/client/particle/TextureSheetParticle for class it/hurts/sskirillss/octolib/particle/BasicColoredParticle in classloader cpw.mods.modlauncher.TransformingClassLoader@4f235107 on thread Thread[#1,main,5,main]
# [19:35:43 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.particle.TextureSheetParticle
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?]
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?]
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?]
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?]
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?]
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?]
# 	at it.hurts.sskirillss.octolib.particle.BasicColoredParticle$Options.<clinit>(BasicColoredParticle.java:271) ~[octolib-1.20.1-0.3.jar%23281!/:1.20.1-0.3]
# 	at it.hurts.sskirillss.octolib.particle.BasicColoredParticle$Factory$Type.<init>(BasicColoredParticle.java:329) ~[octolib-1.20.1-0.3.jar%23281!/:1.20.1-0.3]
# 	at net.minecraftforge.registries.DeferredRegister.lambda$addEntries$1(DeferredRegister.java:386) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraftforge.registries.RegisterEvent.register(RegisterEvent.java:59) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraftforge.registries.DeferredRegister.addEntries(DeferredRegister.java:386) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraftforge.registries.DeferredRegister$EventDispatcher.handleEvent(DeferredRegister.java:328) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraftforge.registries.__EventDispatcher_handleEvent_RegisterEvent.invoke(.dynamic) ~[?:?]
# 	at net.minecraftforge.eventbus.ASMEventHandler.invoke(ASMEventHandler.java:73) ~[eventbus-6.0.5.jar%23145!/:?]
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:319) ~[eventbus-6.0.5.jar%23145!/:?]
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:299) ~[eventbus-6.0.5.jar%23145!/:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.acceptEvent(FMLModContainer.java:155) ~[javafmllanguage-1.20.1-47.2.20.jar%23298!/:?]
# 	at net.minecraftforge.fml.ModLoader.lambda$postEventWithWrapInModOrder$33(ModLoader.java:346) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at java.lang.Iterable.forEach(Iterable.java:75) ~[?:?]
# 	at net.minecraftforge.fml.ModList.forEachModInOrder(ModList.java:227) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at net.minecraftforge.fml.ModLoader.postEventWithWrapInModOrder(ModLoader.java:344) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at net.minecraftforge.fml.ModLoader.postEventWrapContainerInModOrder(ModLoader.java:337) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at net.minecraftforge.registries.GameData.postRegisterEvents(GameData.java:329) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraftforge.common.ForgeStatesProvider.lambda$new$4(ForgeStatesProvider.java:25) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraftforge.fml.ModLoader.handleInlineTransition(ModLoader.java:217) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at net.minecraftforge.fml.ModLoader.lambda$dispatchAndHandleError$19(ModLoader.java:209) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at java.util.Optional.ifPresent(Optional.java:178) ~[?:?]
# 	at net.minecraftforge.fml.ModLoader.dispatchAndHandleError(ModLoader.java:209) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at net.minecraftforge.fml.ModLoader.lambda$gatherAndInitializeMods$13(ModLoader.java:183) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at java.lang.Iterable.forEach(Iterable.java:75) ~[?:?]
# 	at net.minecraftforge.fml.ModLoader.gatherAndInitializeMods(ModLoader.java:183) ~[fmlcore-1.20.1-47.2.20.jar%23297!/:?]
# 	at net.minecraftforge.server.loading.ServerModLoader.load(ServerModLoader.java:30) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraft.server.Main.main(Main.java:165) ~[server-1.20.1-20230612.114412-srg.jar%23296!/:?]
# 	at jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:103) ~[?:?]
# 	at java.lang.reflect.Method.invoke(Method.java:580) ~[?:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.runTarget(CommonLaunchHandler.java:111) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.serverService(CommonLaunchHandler.java:103) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonServerLaunchHandler.lambda$makeService$0(CommonServerLaunchHandler.java:27) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandlerDecorator.launch(LaunchServiceHandlerDecorator.java:30) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:53) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:71) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.run(Launcher.java:108) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.main(Launcher.java:78) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:26) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:23) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.bootstraplauncher.BootstrapLauncher.main(BootstrapLauncher.java:141) [bootstraplauncher-1.1.2.jar:?]
# 	at com.mohistmc.MohistMCStart.main(MohistMCStart.java:106) [mohist.jar:1.20.1-580]
# [19:35:44 INFO]: Registered the FluidEffect with Unique ID of minecraft:water for Water (Fluid Amount Required: 1000) with the ID 0
# [19:35:44 INFO]: Registered the FluidEffect with Unique ID of minecraft:lava for Lava (Fluid Amount Required: 1000) with the ID 1
# [19:35:44 INFO]: Registered the FluidEffect with Unique ID of travelersbackpack:potion for Uncraftable Potion (Fluid Amount Required: 250) with the ID 2
# [19:35:44 INFO]: Registered the FluidEffect with Unique ID of minecraft:milk for Milk (Fluid Amount Required: 1000) with the ID 3
# [19:35:45 INFO]: Finished mod setup in: [33, 1, 0, 0, 0, 0, 10, 1] ms
# [19:35:45 INFO]: Initialized color sets in 32ms
# [19:35:45 INFO]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [19:35:45 INFO]: Registered region minecraft:nether to index 0 for type NETHER
# [19:35:45 INFO]: Registered region biomesoplenty:overworld_primary to index 1 for type OVERWORLD
# [19:35:45 INFO]: Registered region biomesoplenty:overworld_secondary to index 2 for type OVERWORLD
# [19:35:45 INFO]: Registered region biomesoplenty:overworld_rare to index 3 for type OVERWORLD
# [19:35:45 INFO]: Registered region biomesoplenty:nether_common to index 1 for type NETHER
# [19:35:45 INFO]: Registered region biomesoplenty:nether_rare to index 2 for type NETHER
# [19:35:45 INFO]: Start animation registration of epicfight
# [19:35:45 INFO]: Assigned animation id 0 to biped/living/idle
# [19:35:45 INFO]: Assigned animation id 1 to biped/living/walk
# [19:35:45 INFO]: Assigned animation id 2 to biped/living/fly
# [19:35:45 INFO]: Assigned animation id 3 to biped/living/creative_idle
# [19:35:45 INFO]: Assigned animation id 4 to biped/living/creative_fly
# [19:35:45 INFO]: Assigned animation id 5 to biped/living/creative_fly_backward
# [19:35:45 INFO]: Assigned animation id 6 to
# [19:35:45 INFO]: Assigned animation id 7 to biped/living/hold_crossbow
# [19:35:45 INFO]: Assigned animation id 8 to biped/living/hold_map_twohand
# [19:35:45 INFO]: Assigned animation id 9 to biped/living/hold_map_offhand
# [19:35:45 INFO]: Assigned animation id 10 to biped/living/hold_map_mainhand
# [19:35:45 INFO]: Assigned animation id 11 to biped/living/hold_map_twohand_move
# [19:35:45 INFO]: Assigned animation id 12 to biped/living/hold_map_offhand_move
# [19:35:45 INFO]: Assigned animation id 13 to biped/living/hold_map_mainhand_move
# [19:35:45 INFO]: Assigned animation id 14 to biped/living/run
# [19:35:45 INFO]: Assigned animation id 15 to biped/living/sneak
# [19:35:45 INFO]: Assigned animation id 16 to biped/living/swim
# [19:35:45 INFO]: Assigned animation id 17 to biped/living/float
# [19:35:45 INFO]: Assigned animation id 18 to biped/living/kneel
# [19:35:45 INFO]: Assigned animation id 19 to biped/living/fall
# [19:35:45 INFO]: Assigned animation id 20 to biped/living/mount
# [19:35:45 INFO]: Assigned animation id 21 to biped/living/sit
# [19:35:45 INFO]: Assigned animation id 22 to biped/living/dig
# [19:35:45 INFO]: Assigned animation id 23 to biped/living/dig_offhand
# [19:35:45 INFO]: Assigned animation id 24 to
# [19:35:45 INFO]: Assigned animation id 25 to biped/combat/bow_aim_mid
# [19:35:45 INFO]: Assigned animation id 26 to biped/combat/bow_shot_mid
# [19:35:45 INFO]: Assigned animation id 27 to biped/living/drink
# [19:35:45 INFO]: Assigned animation id 28 to biped/living/drink
# [19:35:45 INFO]: Assigned animation id 29 to biped/living/drink_offhand
# [19:35:45 INFO]: Assigned animation id 30 to biped/living/eat
# [19:35:45 INFO]: Assigned animation id 31 to biped/living/eat
# [19:35:45 INFO]: Assigned animation id 32 to biped/living/eat_offhand
# [19:35:45 INFO]: Assigned animation id 33 to biped/living/spyglass
# [19:35:45 INFO]: Assigned animation id 34 to biped/living/spyglass
# [19:35:45 INFO]: Assigned animation id 35 to biped/living/spyglass_offhand
# [19:35:45 INFO]: Assigned animation id 36 to biped/combat/crossbow_aim_mid
# [19:35:45 INFO]: Assigned animation id 37 to biped/combat/crossbow_shot_mid
# [19:35:45 INFO]: Assigned animation id 38 to biped/combat/crossbow_reload
# [19:35:45 INFO]: Assigned animation id 39 to biped/living/jump
# [19:35:45 INFO]: Assigned animation id 40 to biped/living/run_spear
# [19:35:45 INFO]: Assigned animation id 41 to biped/living/shield
# [19:35:45 INFO]: Assigned animation id 42 to biped/living/shield
# [19:35:45 INFO]: Assigned animation id 43 to biped/living/shield_mirror
# [19:35:45 INFO]: Assigned animation id 44 to biped/living/hold_greatsword
# [19:35:45 INFO]: Assigned animation id 45 to biped/living/hold_uchigatana_sheath
# [19:35:45 INFO]: Assigned animation id 46 to biped/living/hold_uchigatana
# [19:35:45 INFO]: Assigned animation id 47 to biped/living/hold_tachi
# [19:35:45 INFO]: Assigned animation id 48 to biped/living/hold_longsword
# [19:35:45 INFO]: Assigned animation id 49 to biped/living/hold_spear
# [19:35:45 INFO]: Assigned animation id 50 to biped/living/hold_dual
# [19:35:45 INFO]: Assigned animation id 51 to biped/living/hold_liechtenauer
# [19:35:45 INFO]: Assigned animation id 52 to biped/living/walk_greatsword
# [19:35:45 INFO]: Assigned animation id 53 to biped/living/walk_spear
# [19:35:45 INFO]: Assigned animation id 54 to biped/living/walk_uchigatana_sheath
# [19:35:45 INFO]: Assigned animation id 55 to biped/living/walk_uchigatana
# [19:35:45 INFO]: Assigned animation id 56 to biped/living/walk_twohand
# [19:35:45 INFO]: Assigned animation id 57 to biped/living/walk_longsword
# [19:35:45 INFO]: Assigned animation id 58 to biped/living/walk_liechtenauer
# [19:35:45 INFO]: Assigned animation id 59 to biped/living/run_greatsword
# [19:35:45 INFO]: Assigned animation id 60 to biped/living/run_uchigatana
# [19:35:45 INFO]: Assigned animation id 61 to biped/living/run_uchigatana_sheath
# [19:35:45 INFO]: Assigned animation id 62 to biped/living/run_dual
# [19:35:45 INFO]: Assigned animation id 63 to biped/living/run_longsword
# [19:35:45 INFO]: Assigned animation id 64 to biped/living/uchigatana_scrap
# [19:35:45 INFO]: Assigned animation id 65 to biped/living/liechtenauer_ready
# [19:35:45 INFO]: Assigned animation id 66 to biped/combat/hit_shield
# [19:35:45 INFO]: Assigned animation id 67 to biped/combat/hit_shield
# [19:35:45 INFO]: Assigned animation id 68 to biped/combat/hit_shield_mirror
# [19:35:45 INFO]: Assigned animation id 69 to biped/living/climb
# [19:35:45 INFO]: Assigned animation id 70 to biped/living/sleep
# [19:35:45 INFO]: Assigned animation id 71 to biped/combat/javelin_aim_mid
# [19:35:45 INFO]: Assigned animation id 72 to biped/combat/javelin_throw_mid
# [19:35:45 INFO]: Assigned animation id 73 to off_highest
# [19:35:45 INFO]: Assigned animation id 74 to off_middle
# [19:35:45 INFO]: Assigned animation id 75 to zombie/idle
# [19:35:45 INFO]: Assigned animation id 76 to zombie/walk
# [19:35:45 INFO]: Assigned animation id 77 to zombie/chase
# [19:35:45 INFO]: Assigned animation id 78 to creeper/idle
# [19:35:45 INFO]: Assigned animation id 79 to creeper/walk
# [19:35:45 INFO]: Assigned animation id 80 to enderman/idle
# [19:35:45 INFO]: Assigned animation id 81 to enderman/walk
# [19:35:45 INFO]: Assigned animation id 82 to enderman/rage_idle
# [19:35:45 INFO]: Assigned animation id 83 to enderman/rage_walk
# [19:35:45 INFO]: Assigned animation id 84 to wither_skeleton/walk
# [19:35:45 INFO]: Assigned animation id 85 to wither_skeleton/chase
# [19:35:45 INFO]: Assigned animation id 86 to wither_skeleton/idle
# [19:35:45 INFO]: Assigned animation id 87 to wither_skeleton/special_spawn
# [19:35:45 INFO]: Assigned animation id 88 to spider/idle
# [19:35:45 INFO]: Assigned animation id 89 to spider/crawl
# [19:35:45 INFO]: Assigned animation id 90 to iron_golem/idle
# [19:35:45 INFO]: Assigned animation id 91 to iron_golem/walk
# [19:35:45 INFO]: Assigned animation id 92 to hoglin/idle
# [19:35:45 INFO]: Assigned animation id 93 to hoglin/walk
# [19:35:45 INFO]: Assigned animation id 94 to illager/idle
# [19:35:45 INFO]: Assigned animation id 95 to illager/walk
# [19:35:45 INFO]: Assigned animation id 96 to illager/idle_aggressive
# [19:35:45 INFO]: Assigned animation id 97 to illager/chase
# [19:35:45 INFO]: Assigned animation id 98 to illager/spellcast
# [19:35:45 INFO]: Assigned animation id 99 to ravager/idle
# [19:35:45 INFO]: Assigned animation id 100 to ravager/walk
# [19:35:45 INFO]: Assigned animation id 101 to vex/idle
# [19:35:45 INFO]: Assigned animation id 102 to vex/flip
# [19:35:45 INFO]: Assigned animation id 103 to piglin/idle
# [19:35:45 INFO]: Assigned animation id 104 to piglin/walk
# [19:35:45 INFO]: Assigned animation id 105 to piglin/zombified_idle
# [19:35:45 INFO]: Assigned animation id 106 to piglin/zombified_walk
# [19:35:45 INFO]: Assigned animation id 107 to piglin/zombified_chase
# [19:35:45 INFO]: Assigned animation id 108 to piglin/celebrate1
# [19:35:45 INFO]: Assigned animation id 109 to piglin/celebrate2
# [19:35:45 INFO]: Assigned animation id 110 to piglin/celebrate3
# [19:35:45 INFO]: Assigned animation id 111 to piglin/admire
# [19:35:45 INFO]: Assigned animation id 112 to wither/idle
# [19:35:45 INFO]: Assigned animation id 113 to biped/skill/guard_spear
# [19:35:45 INFO]: Assigned animation id 114 to biped/skill/guard_sword
# [19:35:45 INFO]: Assigned animation id 115 to biped/skill/guard_dualsword
# [19:35:45 INFO]: Assigned animation id 116 to biped/skill/guard_greatsword
# [19:35:45 INFO]: Assigned animation id 117 to biped/skill/guard_uchigatana
# [19:35:45 INFO]: Assigned animation id 118 to biped/skill/guard_longsword
# [19:35:45 INFO]: Assigned animation id 119 to biped/skill/steel_whirlwind_charging
# [19:35:45 INFO]: Assigned animation id 120 to biped/skill/roll_forward
# [19:35:45 INFO]: Assigned animation id 121 to biped/skill/roll_backward
# [19:35:45 INFO]: Assigned animation id 122 to biped/skill/step_forward
# [19:35:45 INFO]: Assigned animation id 123 to biped/skill/step_backward
# [19:35:45 INFO]: Assigned animation id 124 to biped/skill/step_left
# [19:35:45 INFO]: Assigned animation id 125 to biped/skill/step_right
# [19:35:45 INFO]: Assigned animation id 126 to biped/skill/knockdown_wakeup_left
# [19:35:45 INFO]: Assigned animation id 127 to biped/skill/knockdown_wakeup_right
# [19:35:45 INFO]: Assigned animation id 128 to biped/skill/demolition_leap_charge
# [19:35:45 INFO]: Assigned animation id 129 to biped/skill/demolition_leap
# [19:35:45 INFO]: Assigned animation id 130 to biped/skill/phantom_ascent_forward
# [19:35:45 INFO]: Assigned animation id 131 to biped/skill/phantom_ascent_backward
# [19:35:45 INFO]: Assigned animation id 132 to biped/combat/fist_auto1
# [19:35:45 INFO]: Assigned animation id 133 to biped/combat/fist_auto2
# [19:35:45 INFO]: Assigned animation id 134 to biped/combat/fist_auto3
# [19:35:45 INFO]: Assigned animation id 135 to biped/combat/fist_dash
# [19:35:45 INFO]: Assigned animation id 136 to biped/combat/sword_auto1
# [19:35:45 INFO]: Assigned animation id 137 to biped/combat/sword_auto2
# [19:35:45 INFO]: Assigned animation id 138 to biped/combat/sword_auto3
# [19:35:45 INFO]: Assigned animation id 139 to biped/combat/sword_dash
# [19:35:45 INFO]: Assigned animation id 140 to biped/combat/greatsword_auto1
# [19:35:45 INFO]: Assigned animation id 141 to biped/combat/greatsword_auto2
# [19:35:45 INFO]: Assigned animation id 142 to biped/combat/greatsword_dash
# [19:35:45 INFO]: Assigned animation id 143 to biped/combat/spear_onehand_auto
# [19:35:45 INFO]: Assigned animation id 144 to biped/combat/spear_twohand_auto1
# [19:35:45 INFO]: Assigned animation id 145 to biped/combat/spear_twohand_auto2
# [19:35:45 INFO]: Assigned animation id 146 to biped/combat/spear_dash
# [19:35:45 INFO]: Assigned animation id 147 to 136
# [19:35:45 INFO]: Assigned animation id 148 to biped/combat/sword_auto4
# [19:35:45 INFO]: Assigned animation id 149 to biped/combat/tool_dash
# [19:35:45 INFO]: Assigned animation id 150 to biped/combat/axe_dash
# [19:35:45 INFO]: Assigned animation id 151 to biped/combat/sword_dual_auto1
# [19:35:45 INFO]: Assigned animation id 152 to biped/combat/sword_dual_auto2
# [19:35:45 INFO]: Assigned animation id 153 to biped/combat/sword_dual_auto3
# [19:35:45 INFO]: Assigned animation id 154 to biped/combat/sword_dual_dash
# [19:35:45 INFO]: Assigned animation id 155 to biped/combat/uchigatana_auto1
# [19:35:45 INFO]: Assigned animation id 156 to biped/combat/uchigatana_auto2
# [19:35:45 INFO]: Assigned animation id 157 to biped/combat/uchigatana_auto3
# [19:35:45 INFO]: Assigned animation id 158 to biped/combat/uchigatana_dash
# [19:35:45 INFO]: Assigned animation id 159 to biped/combat/uchigatana_sheath_auto
# [19:35:45 INFO]: Assigned animation id 160 to biped/combat/uchigatana_sheath_dash
# [19:35:45 INFO]: Assigned animation id 161 to biped/combat/axe_auto1
# [19:35:45 INFO]: Assigned animation id 162 to biped/combat/axe_auto2
# [19:35:45 INFO]: Assigned animation id 163 to biped/combat/longsword_auto1
# [19:35:45 INFO]: Assigned animation id 164 to biped/combat/longsword_auto2
# [19:35:45 INFO]: Assigned animation id 165 to biped/combat/longsword_auto3
# [19:35:45 INFO]: Assigned animation id 166 to biped/combat/longsword_dash
# [19:35:45 INFO]: Assigned animation id 167 to biped/combat/longsword_liechtenauer_auto1
# [19:35:45 INFO]: Assigned animation id 168 to biped/combat/longsword_liechtenauer_auto2
# [19:35:45 INFO]: Assigned animation id 169 to biped/combat/longsword_liechtenauer_auto3
# [19:35:45 INFO]: Assigned animation id 170 to biped/combat/tachi_auto1
# [19:35:45 INFO]: Assigned animation id 171 to biped/combat/tachi_auto2
# [19:35:45 INFO]: Assigned animation id 172 to biped/combat/tachi_auto3
# [19:35:45 INFO]: Assigned animation id 173 to biped/combat/tachi_dash
# [19:35:45 INFO]: Assigned animation id 174 to biped/combat/dagger_auto1
# [19:35:45 INFO]: Assigned animation id 175 to biped/combat/dagger_auto2
# [19:35:45 INFO]: Assigned animation id 176 to biped/combat/dagger_auto3
# [19:35:45 INFO]: Assigned animation id 177 to biped/combat/dagger_dash
# [19:35:45 INFO]: Assigned animation id 178 to biped/combat/dagger_dual_auto1
# [19:35:45 INFO]: Assigned animation id 179 to biped/combat/dagger_dual_auto2
# [19:35:45 INFO]: Assigned animation id 180 to biped/combat/dagger_dual_auto3
# [19:35:45 INFO]: Assigned animation id 181 to biped/combat/dagger_dual_auto4
# [19:35:45 INFO]: Assigned animation id 182 to biped/combat/dagger_dual_dash
# [19:35:45 INFO]: Assigned animation id 183 to biped/combat/trident_auto1
# [19:35:45 INFO]: Assigned animation id 184 to biped/combat/trident_auto2
# [19:35:45 INFO]: Assigned animation id 185 to biped/combat/trident_auto3
# [19:35:45 INFO]: Assigned animation id 186 to biped/combat/sword_airslash
# [19:35:45 INFO]: Assigned animation id 187 to biped/combat/sword_dual_airslash
# [19:35:45 INFO]: Assigned animation id 188 to biped/combat/uchigatana_airslash
# [19:35:45 INFO]: Assigned animation id 189 to biped/combat/uchigatana_sheath_airslash
# [19:35:45 INFO]: Assigned animation id 190 to biped/combat/spear_onehand_airslash
# [19:35:45 INFO]: Assigned animation id 191 to biped/combat/spear_twohand_airslash
# [19:35:45 INFO]: Assigned animation id 192 to biped/combat/longsword_airslash
# [19:35:45 INFO]: Assigned animation id 193 to biped/combat/greatsword_airslash
# [19:35:45 INFO]: Assigned animation id 194 to biped/combat/fist_airslash
# [19:35:45 INFO]: Assigned animation id 195 to biped/combat/dagger_airslash
# [19:35:45 INFO]: Assigned animation id 196 to 187
# [19:35:45 INFO]: Assigned animation id 197 to biped/combat/axe_airslash
# [19:35:45 INFO]: Assigned animation id 198 to biped/combat/sword_mount_attack
# [19:35:45 INFO]: Assigned animation id 199 to biped/combat/spear_mount_attack
# [19:35:45 INFO]: Assigned animation id 200 to biped/combat/mob_onehand1
# [19:35:45 INFO]: Assigned animation id 201 to biped/combat/mob_onehand2
# [19:35:45 INFO]: Assigned animation id 202 to biped/combat/mob_greatsword1
# [19:35:45 INFO]: Assigned animation id 203 to biped/combat/mob_tachi_special
# [19:35:45 INFO]: Assigned animation id 204 to biped/combat/mob_spear_onehand
# [19:35:45 INFO]: Assigned animation id 205 to biped/combat/mob_spear_twohand1
# [19:35:45 INFO]: Assigned animation id 206 to biped/combat/mob_spear_twohand2
# [19:35:45 INFO]: Assigned animation id 207 to biped/combat/mob_spear_twohand3
# [19:35:45 INFO]: Assigned animation id 208 to biped/combat/mob_sword_dual1
# [19:35:45 INFO]: Assigned animation id 209 to biped/combat/mob_sword_dual2
# [19:35:45 INFO]: Assigned animation id 210 to biped/combat/mob_sword_dual3
# [19:35:45 INFO]: Assigned animation id 211 to biped/combat/mob_longsword1
# [19:35:45 INFO]: Assigned animation id 212 to biped/combat/mob_longsword2
# [19:35:45 INFO]: Assigned animation id 213 to biped/combat/mob_uchigatana1
# [19:35:45 INFO]: Assigned animation id 214 to biped/combat/mob_uchigatana2
# [19:35:45 INFO]: Assigned animation id 215 to biped/combat/mob_uchigatana3
# [19:35:45 INFO]: Assigned animation id 216 to biped/combat/mob_dagger_onehand1
# [19:35:45 INFO]: Assigned animation id 217 to biped/combat/mob_dagger_onehand2
# [19:35:45 INFO]: Assigned animation id 218 to biped/combat/mob_dagger_onehand3
# [19:35:45 INFO]: Assigned animation id 219 to biped/combat/mob_dagger_twohand1
# [19:35:45 INFO]: Assigned animation id 220 to biped/combat/mob_dagger_twohand2
# [19:35:45 INFO]: Assigned animation id 221 to biped/combat/mob_throw
# [19:35:45 INFO]: Assigned animation id 222 to biped/skill/guard_sword_hit
# [19:35:45 INFO]: Assigned animation id 223 to biped/skill/guard_sword_hit_active1
# [19:35:45 INFO]: Assigned animation id 224 to biped/skill/guard_sword_hit_active2
# [19:35:45 INFO]: Assigned animation id 225 to biped/skill/guard_sword_hit_active3
# [19:35:45 INFO]: Assigned animation id 226 to biped/skill/guard_longsword_hit_active1
# [19:35:45 INFO]: Assigned animation id 227 to biped/skill/guard_longsword_hit_active2
# [19:35:45 INFO]: Assigned animation id 228 to biped/skill/guard_dualsword_hit
# [19:35:45 INFO]: Assigned animation id 229 to biped/skill/guard_break1
# [19:35:45 INFO]: Assigned animation id 230 to biped/skill/guard_break2
# [19:35:45 INFO]: Assigned animation id 231 to biped/skill/guard_longsword_hit
# [19:35:45 INFO]: Assigned animation id 232 to biped/skill/guard_spear_hit
# [19:35:45 INFO]: Assigned animation id 233 to biped/skill/guard_greatsword_hit
# [19:35:45 INFO]: Assigned animation id 234 to biped/skill/guard_uchigatana_hit
# [19:35:45 INFO]: Assigned animation id 235 to biped/skill/greatsword_slam
# [19:35:45 INFO]: Assigned animation id 236 to biped/skill/revelation_normal
# [19:35:45 INFO]: Assigned animation id 237 to biped/skill/revelation_twohand
# [19:35:45 INFO]: Assigned animation id 238 to biped/combat/hit_short
# [19:35:45 INFO]: Assigned animation id 239 to biped/combat/hit_long
# [19:35:45 INFO]: Assigned animation id 240 to biped/combat/hit_on_mount
# [19:35:45 INFO]: Assigned animation id 241 to biped/living/landing
# [19:35:45 INFO]: Assigned animation id 242 to biped/combat/knockdown
# [19:35:45 INFO]: Assigned animation id 243 to biped/living/death
# [19:35:45 INFO]: Assigned animation id 244 to creeper/hit_short
# [19:35:45 INFO]: Assigned animation id 245 to creeper/hit_long
# [19:35:45 INFO]: Assigned animation id 246 to creeper/death
# [19:35:45 INFO]: Assigned animation id 247 to enderman/hit_short
# [19:35:45 INFO]: Assigned animation id 248 to enderman/hit_long
# [19:35:45 INFO]: Assigned animation id 249 to enderman/neutralized
# [19:35:45 INFO]: Assigned animation id 250 to enderman/convert_rage
# [19:35:45 INFO]: Assigned animation id 251 to enderman/tp_kick1
# [19:35:45 INFO]: Assigned animation id 252 to enderman/tp_kick2
# [19:35:45 INFO]: Assigned animation id 253 to enderman/rush_kick
# [19:35:45 INFO]: Assigned animation id 254 to enderman/jump_kick
# [19:35:45 INFO]: Assigned animation id 255 to enderman/knee
# [19:35:45 INFO]: Assigned animation id 256 to enderman/kick_twice
# [19:35:45 INFO]: Assigned animation id 257 to enderman/grasp
# [19:35:45 INFO]: Assigned animation id 258 to enderman/death
# [19:35:45 INFO]: Assigned animation id 259 to enderman/teleport
# [19:35:45 INFO]: Assigned animation id 260 to dragon/idle
# [19:35:45 INFO]: Assigned animation id 261 to dragon/walk
# [19:35:45 INFO]: Assigned animation id 262 to dragon/fly
# [19:35:45 INFO]: Assigned animation id 263 to dragon/death
# [19:35:45 INFO]: Assigned animation id 264 to dragon/ground_to_fly
# [19:35:45 INFO]: Assigned animation id 265 to dragon/fly_to_ground
# [19:35:45 INFO]: Assigned animation id 266 to dragon/attack1
# [19:35:45 INFO]: Assigned animation id 267 to dragon/attack2
# [19:35:45 INFO]: Assigned animation id 268 to dragon/attack3
# [19:35:45 INFO]: Assigned animation id 269 to dragon/attack4
# [19:35:45 INFO]: Assigned animation id 270 to dragon/attack4_recovery
# [19:35:45 INFO]: Assigned animation id 271 to dragon/fireball
# [19:35:45 INFO]: Assigned animation id 272 to dragon/airstrike
# [19:35:45 INFO]: Assigned animation id 273 to dragon/backjump_prepare
# [19:35:45 INFO]: Assigned animation id 274 to dragon/backjump_move
# [19:35:45 INFO]: Assigned animation id 275 to dragon/backjump_recovery
# [19:35:45 INFO]: Assigned animation id 276 to dragon/crystal_link
# [19:35:45 INFO]: Assigned animation id 277 to dragon/neutralized
# [19:35:45 INFO]: Assigned animation id 278 to dragon/neutralized_recovery
# [19:35:45 INFO]: Assigned animation id 279 to spider/attack
# [19:35:45 INFO]: Assigned animation id 280 to spider/jump_attack
# [19:35:45 INFO]: Assigned animation id 281 to spider/hit
# [19:35:45 INFO]: Assigned animation id 282 to spider/neutralized
# [19:35:45 INFO]: Assigned animation id 283 to spider/death
# [19:35:45 INFO]: Assigned animation id 284 to iron_golem/attack1
# [19:35:45 INFO]: Assigned animation id 285 to iron_golem/attack2
# [19:35:45 INFO]: Assigned animation id 286 to iron_golem/attack3
# [19:35:45 INFO]: Assigned animation id 287 to iron_golem/attack4
# [19:35:45 INFO]: Assigned animation id 288 to iron_golem/death
# [19:35:45 INFO]: Assigned animation id 289 to illager/swing_axe1
# [19:35:45 INFO]: Assigned animation id 290 to illager/swing_axe2
# [19:35:45 INFO]: Assigned animation id 291 to illager/swing_axe3
# [19:35:45 INFO]: Assigned animation id 292 to piglin/death
# [19:35:45 INFO]: Assigned animation id 293 to hoglin/death
# [19:35:45 INFO]: Assigned animation id 294 to hoglin/attack
# [19:35:45 INFO]: Assigned animation id 295 to ravager/death
# [19:35:45 INFO]: Assigned animation id 296 to ravager/groggy
# [19:35:45 INFO]: Assigned animation id 297 to ravager/attack1
# [19:35:45 INFO]: Assigned animation id 298 to ravager/attack2
# [19:35:45 INFO]: Assigned animation id 299 to ravager/attack3
# [19:35:45 INFO]: Assigned animation id 300 to vex/hit
# [19:35:45 INFO]: Assigned animation id 301 to vex/death
# [19:35:45 INFO]: Assigned animation id 302 to vex/charge
# [19:35:45 INFO]: Assigned animation id 303 to vex/neutralized
# [19:35:45 INFO]: Assigned animation id 304 to witch/drink
# [19:35:45 INFO]: Assigned animation id 305 to wither_skeleton/sword_attack1
# [19:35:45 INFO]: Assigned animation id 306 to wither_skeleton/sword_attack2
# [19:35:45 INFO]: Assigned animation id 307 to wither_skeleton/sword_attack3
# [19:35:45 INFO]: Assigned animation id 308 to wither/rush
# [19:35:45 INFO]: Assigned animation id 309 to wither/death
# [19:35:45 INFO]: Assigned animation id 310 to wither/neutralized
# [19:35:45 INFO]: Assigned animation id 311 to wither/spell_wither_armor
# [19:35:45 INFO]: Assigned animation id 312 to wither/charging_blocked
# [19:35:45 INFO]: Assigned animation id 313 to wither/ghost_stand
# [19:35:45 INFO]: Assigned animation id 314 to wither/swirl
# [19:35:45 INFO]: Assigned animation id 315 to wither/laser
# [19:35:45 INFO]: Assigned animation id 316 to wither/backflip
# [19:35:45 INFO]: Assigned animation id 317 to zombie/attack1
# [19:35:45 INFO]: Assigned animation id 318 to zombie/attack2
# [19:35:45 INFO]: Assigned animation id 319 to zombie/attack3
# [19:35:45 INFO]: Assigned animation id 320 to biped/skill/sweeping_edge
# [19:35:45 INFO]: Assigned animation id 321 to biped/skill/dancing_edge
# [19:35:45 INFO]: Assigned animation id 322 to biped/skill/the_guillotine
# [19:35:45 INFO]: Assigned animation id 323 to biped/skill/heartpiercer
# [19:35:45 INFO]: Assigned animation id 324 to 146
# [19:35:45 INFO]: Assigned animation id 325 to biped/skill/grasping_spire_second
# [19:35:45 INFO]: Assigned animation id 326 to biped/skill/steel_whirlwind
# [19:35:45 INFO]: Assigned animation id 327 to biped/skill/battojutsu
# [19:35:45 INFO]: Assigned animation id 328 to biped/skill/battojutsu_dash
# [19:35:45 INFO]: Assigned animation id 329 to biped/skill/rushing_tempo1
# [19:35:45 INFO]: Assigned animation id 330 to biped/skill/rushing_tempo2
# [19:35:45 INFO]: Assigned animation id 331 to biped/skill/rushing_tempo3
# [19:35:45 INFO]: Assigned animation id 332 to biped/skill/relentless_combo
# [19:35:45 INFO]: Assigned animation id 333 to biped/skill/eviscerate_first
# [19:35:45 INFO]: Assigned animation id 334 to biped/skill/eviscerate_second
# [19:35:45 INFO]: Assigned animation id 335 to biped/skill/blade_rush_combo1
# [19:35:45 INFO]: Assigned animation id 336 to biped/skill/blade_rush_combo2
# [19:35:45 INFO]: Assigned animation id 337 to biped/skill/blade_rush_combo3
# [19:35:45 INFO]: Assigned animation id 338 to biped/interact/blade_rush_hit
# [19:35:45 INFO]: Assigned animation id 339 to biped/skill/blade_rush_execute
# [19:35:45 INFO]: Assigned animation id 340 to biped/skill/blade_rush_failed
# [19:35:45 INFO]: Assigned animation id 341 to biped/skill/blade_rush_try
# [19:35:45 INFO]: Assigned animation id 342 to biped/skill/wrathful_lighting
# [19:35:45 INFO]: Assigned animation id 343 to biped/skill/tsunami
# [19:35:45 INFO]: Assigned animation id 344 to biped/skill/tsunami_reinforced
# [19:35:45 INFO]: Assigned animation id 345 to biped/skill/everlasting_allegiance_call
# [19:35:45 INFO]: Assigned animation id 346 to biped/skill/everlasting_allegiance_catch
# [19:35:45 INFO]: Assigned animation id 347 to biped/skill/sharp_stab
# [19:35:45 INFO]: Got IMC []
# [19:35:50 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [19:35:53 ERROR]: Cristel Lib Config Pack has no data
# [19:35:53 WARN]: T&T Waystone Patch Pack accepted!
# [19:35:53 INFO]: Generated runtime SERVER_DATA for pack Supplementaries Generated Pack (supplementaries) in: 34 ms
# [19:35:53 ERROR]: Invalid path in pack: fokastudio:worldgen/biome/README.md, ignoring
# [19:35:56 INFO]: Adding datapack listener capsid_recipes
# [19:35:56 INFO]: Adding datapack listener altar_of_amethyst_recipes
# [19:35:57 WARN]: Found loot table element validation problem in {loot_tables:undead_revamp2:entities/theheavy}.pools[2].entries[1].functions[1]: Parameters [<parameter minecraft:tool>] are not provided in this context
# [19:35:57 WARN]: Found loot table element validation problem in {loot_tables:undead_revamp2:entities/slaveman}.pools[3].entries[0].functions[1]: Parameters [<parameter minecraft:tool>] are not provided in this context
# [19:35:57 ERROR]: Parsing error loading recipe create:cutting/compat/biomesoplenty/cherry_wood
# com.google.gson.JsonSyntaxException: Unknown item 'biomesoplenty:cherry_wood'
# 	at net.minecraft.world.item.crafting.ShapedRecipe.m_151280_(ShapedRecipe.java:361) ~[server-1.20.1-20230612.114412-srg.jar%23296!/:?]
# 	at java.util.Optional.orElseThrow(Optional.java:403) ~[?:?]
# 	at net.minecraft.world.item.crafting.ShapedRecipe.m_151278_(ShapedRecipe.java:360) ~[server-1.20.1-20230612.114412-srg.jar%23296!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_43919_(Ingredient.java:229) ~[server-1.20.1-20230612.114412-srg.jar%23296!/:?]
# 	at net.minecraftforge.common.crafting.VanillaIngredientSerializer.parse(VanillaIngredientSerializer.java:27) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraftforge.common.crafting.CraftingHelper.getIngredient(CraftingHelper.java:148) ~[forge-1.20.1-47.2.20-universal.jar%23301!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_288218_(Ingredient.java:204) ~[server-1.20.1-20230612.114412-srg.jar%23296!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_43917_(Ingredient.java:199) ~[server-1.20.1-20230612.114412-srg.jar%23296!/:?]
# 	at com.simibubi.create.content.processing.recipe.ProcessingRecipeSerializer.readFromJson(ProcessingRecipeSerializer.java:66) ~[create-1.20.1-0.5.1.f.jar%23257!/:0.5.1.f]
# 	at com.simibubi.create.content.processing.recipe.ProcessingRecipeSerializer.fromJson(ProcessingRecipeSerializer.java:154) ~[create-1.20.1-0.5.1.f.jar%23257!/:0.5.1.f]
# ...
# [19:36:31 INFO]: Preparing spawn area: 0%
# [19:36:31 INFO]: Preparing spawn area: 0%
# [19:36:31 INFO]: Preparing spawn area: 0%
# [19:36:31 INFO]: Preparing spawn area: 0%
# [19:36:31 INFO]: Preparing spawn area: 14%
# [19:36:32 INFO]: Time elapsed: 4954 ms
# [19:36:32 INFO]: Preparing start region for dimension minecraft:the_nether
# [19:36:33 INFO]: Preparing spawn area: 0%
# [19:36:33 INFO]: Preparing spawn area: 0%
# [19:36:33 INFO]: Preparing spawn area: 0%
# [19:36:33 INFO]: Preparing spawn area: 0%
# [19:36:34 INFO]: Preparing spawn area: 24%
# [19:36:34 INFO]: Time elapsed: 2348 ms
# [19:36:34 INFO]: Preparing start region for dimension graveyard:past
# [19:36:36 INFO]: Preparing spawn area: 0%
# [19:36:36 INFO]: Preparing spawn area: 0%
# [19:36:36 INFO]: Preparing spawn area: 0%
# [19:36:36 INFO]: Preparing spawn area: 0%
# [19:36:36 INFO]: Preparing spawn area: 0%
# [19:36:37 INFO]: Preparing spawn area: 0%
# [19:36:37 INFO]: Preparing spawn area: 79%
# [19:36:37 INFO]: Time elapsed: 3078 ms
# [19:36:37 INFO]: Preparing start region for dimension minecraft:the_end
# [19:36:38 INFO]: Preparing spawn area: 0%
# [19:36:38 INFO]: Preparing spawn area: 0%
# [19:36:38 INFO]: Preparing spawn area: 0%
# [19:36:39 INFO]: Preparing spawn area: 60%
# [19:36:39 INFO]: Time elapsed: 1640 ms
# [19:36:39 INFO]: [Mohist] Enabling Mohist v1.20.1
# [19:36:39 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [19:36:39 INFO]: Done (36.789s)! For help, type "help"
# [19:36:39 INFO]: Successfully initialized permission handler forge:default_handler
# [19:36:39 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [19:38:34 INFO]: Dr Dante  joined the game
# [19:38:34 INFO]: Dr Dante [/127.0.0.1:50898] logged in with entity id 952 at ([world]-534.760702923771, 69.0, 922.3000000119209)
# [19:39:15 INFO]: Dr Dante  has made the advancement [advancements.adventure.way_sign.title]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:07:41 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [20:07:41 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [20:07:41 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [20:07:41 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [20:07:41 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [20:07:41 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [20:07:41 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [20:07:41 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [20:07:56 INFO]: Dr Dante  has made the advancement [tombstone.advancement.first_knowledge.title]
# [20:07:56 INFO]: Dr Dante  has made the advancement [tombstone.advancement.ambush.title]
# [20:10:01 INFO]: Dr Dante  lost connection: Disconnected
# [20:10:01 INFO]: Dr Dante  left the game
# [20:10:14 INFO]: Dr Dante  joined the game
# [20:10:14 INFO]: Dr Dante [/127.0.0.1:47540] logged in with entity id 9185 at ([world]-1469.0970117939933, 63.5, -1252.9421122722263)
# [20:10:35 INFO]: Dr Dante  lost connection: Disconnected
# [20:10:35 INFO]: Dr Dante  left the game
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:48:25 INFO]: Dr Dante  joined the game
# [20:48:25 INFO]: Dr Dante [/127.0.0.1:51982] logged in with entity id 9541 at ([world]-1467.435972635333, 63.0, -1253.2073916290058)
# [20:49:55 INFO]: Searching for closest structure among [ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_snowy_taiga], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_wooded_badlands], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_classic], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_ocean], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_mediterranean], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_badlands], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_iberian], ResourceKey[minecraft:worldgen/structure / minecraft:village_snowy]] from pos BlockPos{x=-1723, y=74, z=-1451}
# [20:49:58 WARN]: Dr Dante  moved too quickly! -15.780979926777945,1.2508673611415873,0.4683317324706877
# [20:52:16 INFO]: Searching for closest structure among [ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_rustic], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_iberian], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_flower_forest], ResourceKey[minecraft:worldgen/structure / minecraft:village_desert], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_nilotic], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_grove], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_swamp], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_sparse_jungle]] from pos BlockPos{x=-1797, y=68, z=-1179}
# [20:53:31 WARN]: Skipping Entity with id
# [20:53:31 WARN]: Skipping Entity with id
# [20:53:33 WARN]: Skipping Entity with id
# [20:53:33 WARN]: Skipping Entity with id
# [20:54:01 ERROR]: Hanging entity at invalid position: BlockPos{x=203, y=48, z=159}
# [20:54:46 INFO]: Searching for closest structure among [ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_meadow], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_swedish], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_tudor], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_nilotic], ResourceKey[minecraft:worldgen/structure / minecraft:village_savanna], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_jungle], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_rustic], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_beach]] from pos BlockPos{x=-2027, y=69, z=-1109}
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:55:30 INFO]: MrEricXX3 joined the game
# [20:55:30 INFO]: MrEricXX3[/127.0.0.1:55938] logged in with entity id 12360 at ([world]-533.2262183509863, 70.875, 915.8911598154821)
# [20:56:40 INFO]: <MrEricXX3> huancayo? xdd
# [20:56:53 INFO]: <Dr Dante > claro pes
# [20:56:57 INFO]: <Dr Dante > el tambo
# [20:57:13 INFO]: <Dr Dante > mano preparate
# [20:57:18 INFO]: <Dr Dante > encontre algo
# [20:57:27 INFO]: <MrEricXX3> ok
# [20:57:36 INFO]: <Dr Dante > si esta gosu t tepeo
# [20:57:47 INFO]: MrEricXX3 issued server command: /summon minecraft:sheep
# [20:57:47 INFO]: [MrEricXX3: Summoned new Sheep]
# [20:57:54 INFO]: MrEricXX3 issued server command: /summon minecraft:sheep
# [20:57:54 INFO]: [MrEricXX3: Summoned new Sheep]
# [20:57:57 INFO]: MrEricXX3 issued server command: /summon minecraft:sheep
# [20:57:57 INFO]: [MrEricXX3: Summoned new Sheep]
# [20:59:55 INFO]: Dr Dante  has reached the goal [advancements.irons_spellbooks.make_inscription_table.title]
# [21:01:59 INFO]: <Dr Dante > tengo dos mesas de inscripcion xd
# [21:02:11 INFO]: <MrEricXX3> eso de los hechizos?
# [21:02:19 INFO]: <MrEricXX3> donde chotas estás
# [21:03:26 INFO]: Created new backpack backup file for Dr Dante  with unique ID ce24e94a-684d-443b-b353-fc58331a9f8c
# [21:03:26 INFO]: Your backpack has been placed at X: -2067 Y: 73 Z: -1301
# [21:03:26 INFO]: Dr Dante  has reached the goal [tombstone.advancement.strong_or_careful.title]
# [21:03:26 INFO]: death.attack.irons_spellbooks.summon_polar_bear
# [21:03:26 INFO]: Dr Dante  has made the advancement [tombstone.advancement.first_grave.title]
# [21:03:26 INFO]: tombstone.message.recovery.save_player.success
# [21:03:51 INFO]: Dr Dante  lost connection: Timed out
# [21:03:51 INFO]: Dr Dante  left the game
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [21:05:27 INFO]: Dr Dante  joined the game
# [21:05:27 INFO]: Dr Dante [/127.0.0.1:56608] logged in with entity id 14976 at ([world]-2065.673436653479, 73.0, -1301.4364121728415)
# [21:06:13 INFO]: <Dr Dante > SDVXC
# [21:06:15 INFO]: <Dr Dante > T
# [21:06:24 INFO]: Dr Dante  has reached the goal [tombstone.advancement.cancel_ghostly_shape.title]
# [21:06:54 INFO]: Dr Dante  has made the advancement [tombstone.advancement.enchant_grave_key.title]
# [21:07:53 INFO]: Dr Dante  has reached the goal [tombstone.advancement.teleport_to_grave.title]
# [21:07:55 INFO]: death.attack.irons_spellbooks.summon_polar_bear
# [21:07:55 INFO]: tombstone.message.recovery.save_player.success
# [21:09:05 INFO]: com.mojang.authlib.GameProfile@6b1c8d17[id=27dce28b-2a47-3dce-8c38-af9e72322522,name=Spyhoo,properties={},legacy=false] (/127.0.0.1:39444) lost connection: Disconnected
# [21:09:22 INFO]: <MrEricXX3> -2066 73 -1302
# [21:11:22 INFO]: com.mojang.authlib.GameProfile@324fcd4f[id=27dce28b-2a47-3dce-8c38-af9e72322522,name=Spyhoo,properties={},legacy=false] (/127.0.0.1:43508) lost connection: Disconnected
# [21:12:42 INFO]: Dr Dante  has made the advancement [advancements.graveyard.root.title]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [21:17:08 WARN]: Invalid statistic in ./world/stats/27dce28b-2a47-3dce-8c38-af9e72322522.json: Don't know what depthcrawler:whiteshard is
# [21:17:08 INFO]: Spyhoo joined the game
# [21:17:08 INFO]: Spyhoo[/127.0.0.1:40072] logged in with entity id 18472 at ([world]-784.8360953438705, 75.0, 706.2997899535764)
# [21:17:53 INFO]: <MrEricXX3> -2066 -1302
# [21:18:03 INFO]: Spyhoo has made the advancement [advancements.alexsmobs.kangaroo.title]
# [21:18:49 INFO]: Searching for closest structure among [ResourceKey[minecraft:worldgen/structure / stellarity:village], ResourceKey[minecraft:worldgen/structure / minecraft:village_taiga], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_birch_forest], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_snowy_taiga], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_savanna_plateau], ResourceKey[minecraft:worldgen/structure / towns_and_towers:village_flower_forest], ResourceKey[minecraft:worldgen/structure / towns_and_towers:exclusives/village_wandering_trader_camp], ResourceKey[minecraft:worldgen/structure / minecraft:village_plains]] from pos BlockPos{x=-1771, y=74, z=629}
# [21:19:34 WARN]: UUID of added entity already exists: Drowned['Drowned'/21838, l='ServerLevel[world]', x=-1864.50, y=56.00, z=675.50]
# [21:21:30 INFO]: Dr Dante  lost connection: Disconnected
# [21:21:30 INFO]: Dr Dante  left the game
# [21:21:33 INFO]: MrEricXX3 lost connection: Disconnected
# [21:21:33 INFO]: MrEricXX3 left the game
# >
